# %%
from PIL import Image
import os,glob, re, json

# %%
orgDir = "01_LabelboxExport/Forest tsumura 2 50m P4Pv2/original"
mskDir = "01_LabelboxExport/Forest tsumura 2 50m P4Pv2/masked"

orgPaths = glob.glob(orgDir + "/*.JPG")
mskPaths = glob.glob(mskDir + "_seg_*/*.png")

mskImagesDir = "02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk"

# %%
def getTreeType_fromPath(Path:str):
    pattern = r'masked_seg_(.*)\\DJI_.*'
    match = re.search(pattern, Path)
    if match:
        treeType = match.group(1)
    return treeType
treeType
# Out:
# 'cedar'

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# 定義
# treeTypeValues = {
#     "cedar":1,
#     "cypress":2
# }
# 書き込み
# with open("treeTypeValues.json","w") as file:
#     json.dump(treeTypeValues, file)


# Opening JSON file
with open('treeTypeValues.json', 'r') as openfile:
 
    # Reading from json file
    treeTypeValues = json.load(openfile)
    
treeTypeValues
# Out:
# {'cedar': 1, 'cypress': 2}

# %%
# 単一樹種分類用

def makeSingleMaskSets(orgPaths:list,mskPaths:list,treeTypes:dict):

    for orgPath in orgPaths:
        orgImgName = os.path.basename(orgPath).split(".")[0]

        for treeType in treeTypes:

            org = np.array(Image.open(orgPath))
            msk_base = np.zeros(org.shape[:2],dtype=np.uint8)

            # オリジナル画像名と、樹種名が含まれているmskパス群を抽出
            for mskPath in filter(lambda x: (orgImgName in x and treeType in x), mskPaths):
                print(mskPath)

                mergedMasksDir = f"{mskImagesDir}_merged_{treeType}"
                os.makedirs(mergedMasksDir, exist_ok=True)

                msk = np.array(Image.open(mskPath).convert("L"))

                # # 値の置換 255->1　単一分類では行わない
                # msk = np.where(msk == 255, treeTypeValues[treeType], 0).astype(np.uint8)
                msk_base = msk_base + msk

            cv2.imwrite(os.path.join(mergedMasksDir,orgImgName+".PNG"), msk_base)

            # 2つの画像を横に並べる
            fig, axs = plt.subplots(1, 2)
            axs[0].imshow(org)
            axs[1].imshow(msk_base, cmap='gray')
            # 表示する
            plt.show()
            plt.close()

            del org,msk_base,msk


makeSingleMaskSets(orgPaths,mskPaths,treeTypes)
# Out:
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0245_cl5tvpw3300433b6g73mdwh4w.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0245_ckxmpapbl00003f65xx7d1bxt.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0245_ckxppv3g400003f65619g5cjx.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0314_cl5tvet7y003j3b6ghl8n2nqu.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmpc7vt00083f65n51ajlfn.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmpdegz000a3f65hzpri986.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmpeuu2000c3f65hs6zmcyz.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmphv4l000h3f65wkzdy3u8.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmvrlzq002n3f650uks41xx.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_cl5tvovpf00403b6gex38eli6.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0065_ckxu403qn000c3f65eml0f3ij.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0065_cl5tvbvoi003h3b6gzzspcxlk.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0065_ckxmplm4g000m3f65coznalll.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0065_ckxmv9qyj001u3f65xei2rc9o.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0065_ckxu428uh000f3f65btzb573u.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0460_cl5tv5gsw00303b6gvxzcrvqb.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0460_ckxmpqite000r3f65qntrv81f.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0460_ckxmsqu8v000n3f653o80fry1.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0460_ckxmv5uzu001p3f650ks5kwoa.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0673_cl5tuaft900073b6gcwwoctt3.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxmq546s00143f65kppmsbgq.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxmq5f0000163f65m5i60dzl.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxmri1b2000i3f65207p0gmm.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxu3yoma00093f65lgenrux9.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_cl5tuhuvj000y3b6gwnv4fknm.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_cl5tuim5n00103b6gkn3z95lw.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0804_cl5ttlyae00033b6h7pwrviza.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxmq9td6001c3f65h09ngq9j.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxmr7fd900003f65xnfnlgd9.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxu3wfss00033f65z7a8rf27.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxu3wvg800053f65eiz79929.png

# %%
# マルチ樹種の分類タスク用

def makeMultiMaskSets(orgPaths:list,mskPaths:list,treeTypes:dict):

    for orgPath in orgPaths:
        orgImgName = os.path.basename(orgPath).split(".")[0]

        org = np.array(Image.open(orgPath))
        msk_base = np.zeros(org.shape[:2],dtype=np.uint8)
        
        for treeType in treeTypes:
            # オリジナル画像名と、樹種名が含まれているmskパス群を抽出
            for mskPath in filter(lambda x: (orgImgName in x and treeType in x), mskPaths):
                print(mskPath)

                mergedMasksDir = f"{mskImagesDir}_merged_MultiChannel_{'+'.join(treeTypes)}"
                os.makedirs(mergedMasksDir, exist_ok=True)

                msk = np.array(Image.open(mskPath).convert("L"))

                msk = np.where(msk == 255, int(treeTypeValues[treeType])*(255//len(treeTypes)), 0).astype(np.uint8)
                msk_base = msk_base + msk
    
        
        mskPath_merged = f"{mergedMasksDir}/{orgImgName}.PNG"
        print(mskPath_merged)
        cv2.imwrite(mskPath_merged, msk_base)

        # 2つの画像を横に並べる
        fig, axs = plt.subplots(1, 2)
        axs[0].imshow(org)
        axs[1].imshow(msk_base, cmap='gray')
        # 表示する
        plt.show()
        del org,msk
        del msk_base


makeMultiMaskSets(orgPaths,mskPaths,treeTypes)
# Out:
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0245_cl5tvpw3300433b6g73mdwh4w.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0245_ckxmpapbl00003f65xx7d1bxt.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0245_ckxppv3g400003f65619g5cjx.png
# 02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk_merged_MultiChannel_cypress+cedar/DJI_0245.PNG
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0314_cl5tvet7y003j3b6ghl8n2nqu.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmpc7vt00083f65n51ajlfn.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmpdegz000a3f65hzpri986.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmpeuu2000c3f65hs6zmcyz.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmphv4l000h3f65wkzdy3u8.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_ckxmvrlzq002n3f650uks41xx.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0314_cl5tvovpf00403b6gex38eli6.png
# 02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk_merged_MultiChannel_cypress+cedar/DJI_0314.PNG
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0065_ckxu403qn000c3f65eml0f3ij.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0065_cl5tvbvoi003h3b6gzzspcxlk.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0065_ckxmplm4g000m3f65coznalll.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0065_ckxmv9qyj001u3f65xei2rc9o.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0065_ckxu428uh000f3f65btzb573u.png
# 02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk_merged_MultiChannel_cypress+cedar/DJI_0065.PNG
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0460_cl5tv5gsw00303b6gvxzcrvqb.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0460_ckxmpqite000r3f65qntrv81f.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0460_ckxmsqu8v000n3f653o80fry1.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0460_ckxmv5uzu001p3f650ks5kwoa.png
# 02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk_merged_MultiChannel_cypress+cedar/DJI_0460.PNG
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0673_cl5tuaft900073b6gcwwoctt3.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxmq546s00143f65kppmsbgq.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxmq5f0000163f65m5i60dzl.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxmri1b2000i3f65207p0gmm.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_ckxu3yoma00093f65lgenrux9.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_cl5tuhuvj000y3b6gwnv4fknm.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0673_cl5tuim5n00103b6gkn3z95lw.png
# 02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk_merged_MultiChannel_cypress+cedar/DJI_0673.PNG
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cypress\DJI_0804_cl5ttlyae00033b6h7pwrviza.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxmq9td6001c3f65h09ngq9j.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxmr7fd900003f65xnfnlgd9.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxu3wfss00033f65z7a8rf27.png
# 01_LabelboxExport/Forest tsumura 2 50m P4Pv2\masked_seg_cedar\DJI_0804_ckxu3wvg800053f65eiz79929.png
# 02_MargedMaskImages/Forest tsumura 2 50m P4Pv2/msk_merged_MultiChannel_cypress+cedar/DJI_0804.PNG

# %%
(255//len(treeTypes))*2
# Out:
# 254

# %%
# Out:
# True
